# %% [markdown]
# # Attrition Prediction using Classification
#
# We will work on the subset of the the synthetic [IBM HR Employees Attrition dataset](https://www.kaggle.com/janiobachmann/attrition-in-an-organization-why-workers-quit/data?select=WA_Fn-UseC_-HR-Employee-Attrition.csv).
#
# The dataset gives information about the employees in the organization and the target variable (Y) is Attrition, which tells whether an employee was replaced or not.  We will look at the variables and different factors that affect employee performance, including factors like work from home sitaution, job role, monthly income etc.
# # Importing the libraries and datasets

# %%
#Basics
import pandas as pd
import numpy as np

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#SkLearn ML General
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn import metrics

#SkLearn ML Algorithms
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import svm

# %% [markdown]
# The original dataset contains around 35 feature variables. We will be using a subset of that and use 14 features in this exercise.

# %%
#Import Data Subset from HREmployeeData.csv
employee_data = pd.read_csv('HREmployeeData.csv')
employee_data
# Out:
#       Attrition  Age  BusinessTravel  DistanceFromHome  JobSatisfaction  \
# 0             1   41               2                 1                4
# 1             0   49               1                 8                2
# 2             1   37               2                 2                3
# 3             0   33               1                 3                3
# 4             0   27               2                 2                2
# ...         ...  ...             ...               ...              ...
# 1465          0   36               1                23                4
# 1466          0   39               2                 6                1
# 1467          0   27               2                 4                2
# 1468          0   49               1                 2                2
# 1469          0   34               2                 8                3
#
#       MaritalStatus  MonthlyIncome  OverTime  StockOptionLevel  \
# ...

# %% [markdown]
# # Data Exploration
#
# We explore our dataset before we dive into the data analytics part.
#
# * We want to know how many features are there in our dataset
# * What the distribution of our data is like.

# %%
#Descriptive stats for the dataset
employee_data.describe()
# Out:
#          Attrition          Age  BusinessTravel  DistanceFromHome  \
# count  1470.000000  1470.000000     1470.000000       1470.000000
# mean      0.161224    36.923810        1.607483          9.192517
# std       0.367863     9.135373        0.665455          8.106864
# min       0.000000    18.000000        0.000000          1.000000
# 25%       0.000000    30.000000        1.000000          2.000000
# 50%       0.000000    36.000000        2.000000          7.000000
# 75%       0.000000    43.000000        2.000000         14.000000
# max       1.000000    60.000000        2.000000         29.000000
#
#        JobSatisfaction  MaritalStatus  MonthlyIncome     OverTime  \
# count      1470.000000    1470.000000    1470.000000  1470.000000
# mean          2.728571       1.097279    6502.931293     0.282993
# std           1.102846       0.730121    4707.956783     0.450606
# min           1.000000       0.000000    1009.000000     0.000000
# ...

# %% [markdown]
# We can explore the target variable (Attrition) using a histogram plot to see how frequently it's values occur in the data.

# %%
#Plot a Histogram of the target variable
employee_data.Attrition.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Attrition of Employees')
plt.ylabel('Occurence of each in the dataset')
plt.xlabel('Attrition')
# Out:
# Text(0.5, 0, 'Attrition')

# %% [markdown]
# From the plot, we can see that most employees were not replaced, but a few (less than 200) were attritioned.

# %% [markdown]
# # Predictive Modelling

# %% [markdown]
# X will contain our independent feature variables and y is our target/outcome variable.

# %%
#Separate x_inputs from y_target variables
x_inputs = employee_data.drop(['Attrition'], axis=1)
y_target = employee_data['Attrition']

# %% [markdown]
# ### Test/Train Split
#
# Split the data into 50% training / testing and initialize each of the classifiers.

# %%
#split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x_inputs, y_target, test_size=0.5, random_state=0)

# %% [markdown]
# Once our dataset is split, we will now initialize each of the classifiers and fit them to our training data.

# %%
# Define the classifiers
classifiers = {
    "classifier_NB":    GaussianNB(),
    "classifier_SVM":   SVC(gamma = 2, C = 1),
    "classifier_KNN":   KNeighborsClassifier(n_neighbors = 3),
    "classifier_DT":    DecisionTreeClassifier(random_state = 0),
    "classifier_RF":    RandomForestClassifier(max_depth = 2, random_state = 0)
}
results = {}
print("Number of mislabeled points out of a total %d points:" % X_test.shape[0])
# Train the classifiers on the training set and test classifiers on unseen test data
for clf_name, clf_model in classifiers.items():
    clf_model.fit(X_train, y_train)
    clf_model.predict(X_test)
    print(clf_name + ": %d" % (y_test != clf_model.predict(X_test)).sum())
    results[clf_name] = clf_model.predict(X_test)
# Out:
# Number of mislabeled points out of a total 735 points:
# classifier_NB: 104
# classifier_SVM: 112
# classifier_KNN: 139
# classifier_DT: 148
# classifier_RF: 109

# %% [markdown]
# # Evaluation Metrics
# We will use Accuracy, Precision, Recall and F₁ and F₂ score to evaluate our model's performance results.

# %%
#Print Evaluation Metrics: Accuracy, Precision, Recall, F1 and F2

print("Accuracy Scores:")
for clf_name, clf_model in results.items():
        print(clf_name + ": ", round(metrics.accuracy_score(y_test, clf_model) * 100,4))

print("\nPrecision Scores:")
for clf_name, clf_model in results.items():
        print(clf_name + ": ", round(metrics.precision_score(y_test, clf_model, average = 'weighted') * 100,4))
        
print("\nRecall Scores:")
for clf_name, clf_model in results.items():
        print(clf_name + ": ", round(metrics.recall_score(y_test, clf_model, average = 'weighted') * 100, 4))

print("\nF₁ Scores:")
for clf_name, clf_model in results.items():
        print(clf_name + ": ", 
              round(metrics.f1_score(y_test, clf_model, average = 'weighted', labels = np.unique(clf_model)) * 100, 4)
             )
        
print("\nF₂ Scores:")
for clf_name, clf_model in results.items():
        print(clf_name + ": ", 
              round(metrics.fbeta_score(y_test, clf_model, average = 'weighted', beta = 0.5) * 100,4)
             )
# Out:
# Accuracy Scores:
# classifier_NB:  85.8503
# classifier_SVM:  84.7619
# classifier_KNN:  81.0884
# classifier_DT:  79.8639
# classifier_RF:  85.1701
#
# Precision Scores:
# classifier_NB:  85.6453
# classifier_SVM:  71.8458
# classifier_KNN:  77.6368
# classifier_DT:  80.7356
# classifier_RF:  87.3784
#
# Recall Scores:
# classifier_NB:  85.8503
# classifier_SVM:  84.7619
# classifier_KNN:  81.0884
# classifier_DT:  79.8639
# classifier_RF:  85.1701
#
# F₁ Scores:
# classifier_NB:  85.7443
# classifier_SVM:  91.7526
# classifier_KNN:  79.0409
# classifier_DT:  80.278
# classifier_RF:  78.7385
#
# F₂ Scores:
# classifier_NB:  85.684
# classifier_SVM:  74.1042
# classifier_KNN:  78.0963
# classifier_DT:  80.5476
# classifier_RF:  76.198
# ...

# %% [markdown]
# ### Summary of Classifier Performance
#
# #### 1. **Accuracy**
#    - **Best:** `classifier_NB` (85.85%) and `classifier_RF` (85.17%)
#    - **Lowest:** `classifier_DT` (79.86%)
#    - **Interpretation:** Accuracy is a measure of how often the classifier correctly predicts the target label. `classifier_NB` (Naive Bayes) and `classifier_RF` (Random Forest) have the highest accuracy, indicating they are most effective at correct classification.
#
# #### 2. **Precision**
#    - **Best:** `classifier_RF` (87.38%)
#    - **Lowest:** `classifier_SVM` (71.85%)
#    - **Interpretation:** Precision is the ratio of true positive predictions to the total number of positive predictions made. A higher precision means fewer false positives. `classifier_RF` has the highest precision, indicating it is more conservative and precise in predicting the positive class.
#
# #### 3. **Recall**
#    - **Best:** `classifier_NB` (85.85%) and `classifier_SVM` (84.76%)
#    - **Lowest:** `classifier_DT` (79.86%)
#    - **Interpretation:** Recall is the ratio of true positives to the actual number of positives. High recall means fewer false negatives. `classifier_NB` and `classifier_SVM` excel in this area, showing they are effective at identifying most of the positive instances.
#
# #### 4. **F₁ Score**
#    - **Best:** `classifier_SVM` (91.75%)
#    - **Lowest:** `classifier_RF` (78.74%)
#    - **Interpretation:** The F₁ score is the harmonic mean of precision and recall, providing a balance between the two. `classifier_SVM` achieves the highest F₁ score, suggesting it provides the best balance between precision and recall.
#
# #### 5. **F₂ Score**
#    - **Best:** `classifier_NB` (85.68%)
#    - **Lowest:** `classifier_RF` (76.20%)
#    - **Interpretation:** The F₂ score gives more weight to recall than precision. `classifier_NB` performs best here, indicating it is particularly good at minimizing false negatives.
#
# ### Conclusion
#
# - **Naive Bayes (`classifier_NB`)**: Consistently performs well across all metrics, making it a strong overall performer, especially for cases where recall is critical.
# - **Support Vector Machine (`classifier_SVM`)**: Although it has the lowest precision, it has the highest F₁ score, indicating a good balance between precision and recall. This makes it a strong choice for scenarios where this balance is important.
